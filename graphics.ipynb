# %%
import pandas as pd
import matplotlib.pyplot as plt

log_file = "logs/training_log_v1.csv"

try:
    data = pd.read_csv(log_file)
    print(f"Archivo '{log_file}' cargado correctamente. Total de {len(data)} épocas registradas.")

    # --- GRÁFICA 1: PÉRDIDAS (LOSSES) ---
    plt.figure(figsize=(12, 6))
    plt.plot(data['Epoch'].to_numpy(), data['Generator_Loss'].to_numpy(), label="Pérdida del Generador (v1)", color="blue")
    plt.plot(data["Epoch"].to_numpy(), data["Discriminator_Loss"].to_numpy(), label="Pérdida del Discriminador (v1)", color="orange")
    plt.title("Evolución de las pérdidas durante el entrenamiento (v1)")
    plt.xlabel("Época")
    plt.ylabel("Pérdida (Loss)")
    plt.legend()
    plt.grid(True)
    # He corregido una pequeña errata en la ruta para guardar, para que coincida con la de la otra gráfica
    plt.savefig("results/v1/grafica_perdidas_v1.png")
    plt.show()
    print("Gráfica de pérdidas guardada como 'grafica_perdidas_v1.png'")

    # --- GRÁFICA 2: PRECISIÓN (ACCURACY) ---
    plt.figure(figsize=(12, 6))
    # AÑADIMOS .to_numpy() a cada columna de pandas
    plt.plot(data['Epoch'].to_numpy(), (data['Discriminator_Accuracy'] * 100).to_numpy(), label='Precisión del Discriminador (v1)', color="green")
    plt.title("Evolución de la precisión del Discriminador (v1)")
    plt.xlabel("Época")
    plt.ylabel("Precisión (%)")
    plt.axhline(y=75, color="r", linestyle='--', label="Equilibrio Ideal (75%)")
    
    plt.legend()
    plt.grid(True)
    plt.savefig("results/v1/grafica_precision_v1.png")
    plt.show()
    print("Gráfica de precisión guardada como 'grafica_precision_v1.png'")

except FileNotFoundError:
    print(f"Error: No se encontró el archivo '{log_file}'. Asegúrate de que está en la misma carpeta que el notebook")
except Exception as e:
    print(f"Ocurrió un error inesperado: {e}")
# Out:
# Archivo 'logs/training_log_v1.csv' cargado correctamente. Total de 500 épocas registradas.
# Gráfica de pérdidas guardada como 'grafica_perdidas_v1.png'
# Gráfica de precisión guardada como 'grafica_precision_v1.png'

# %%
import pandas as pd
import matplotlib.pyplot as plt

log_file = "logs/training_log_v2.csv"

try:
    data = pd.read_csv(log_file)
    print(f"Archivo '{log_file}' cargado correctamente. Total de {len(data)} épocas registradas.")

    # --- GRÁFICA 1: PÉRDIDAS (LOSSES) ---
    plt.figure(figsize=(12, 6))
    plt.plot(data['Epoch'].to_numpy(), data['Generator_Loss'].to_numpy(), label="Pérdida del Generador (v2)", color="blue")
    plt.plot(data["Epoch"].to_numpy(), data["Discriminator_Loss"].to_numpy(), label="Pérdida del Discriminador (v2)", color="orange")
    plt.title("Evolución de las pérdidas durante el entrenamiento (v2)")
    plt.xlabel("Época")
    plt.ylabel("Pérdida (Loss)")
    plt.legend()
    plt.grid(True)
    plt.savefig("results/v2/grafica_perdidas_v2.png")
    plt.show()
    print("Gráfica de pérdidas guardada como 'grafica_perdidas_v2.png'")

    # --- GRÁFICA 2: PRECISIÓN (ACCURACY) ---
    plt.figure(figsize=(12, 6))
    plt.plot(data['Epoch'].to_numpy(), (data['Discriminator_Accuracy'] * 100).to_numpy(), label='Precisión del Discriminador (v2)', color="green")
    plt.title("Evolución de la precisión del Discriminador (v2)")
    plt.xlabel("Época")
    plt.ylabel("Precisión (%)")
    plt.axhline(y=75, color="r", linestyle='--', label="Equilibrio Ideal (75%)")
    plt.legend()
    plt.grid(True)
    plt.savefig("results/v2/grafica_precision_v2.png")
    plt.show()
    print("Gráfica de precisión guardada como 'grafica_precision_v2.png'")

except FileNotFoundError:
    print(f"Error: No se encontró el archivo '{log_file}'. Asegúrate de que está en la misma carpeta que el notebook")
except Exception as e:
    print(f"Ocurrió un error inesperado: {e}")
# Out:
# Archivo 'logs/training_log_v2.csv' cargado correctamente. Total de 1024 épocas registradas.
# Gráfica de pérdidas guardada como 'grafica_perdidas_v2.png'
# Gráfica de precisión guardada como 'grafica_precision_v2.png'
